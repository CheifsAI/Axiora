# %%
import pandas as pd
from LLM import llama3b
from Visualizer import Visualizer
from DataAnalyzer import DataAnalyzer

# %%
df = pd.read_csv("Test_Datasets/laptop_price.csv", encoding='latin1')
df.head(5)
# Out:
#    laptop_ID Company      Product   TypeName  Inches  \
# 0          1   Apple  MacBook Pro  Ultrabook    13.3
# 1          2   Apple  Macbook Air  Ultrabook    13.3
# 2          3      HP       250 G6   Notebook    15.6
# 3          4   Apple  MacBook Pro  Ultrabook    15.4
# 4          5   Apple  MacBook Pro  Ultrabook    13.3
#
#                      ScreenResolution                         Cpu   Ram  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz   8GB
# 1                            1440x900        Intel Core i5 1.8GHz   8GB
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   8GB
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz  16GB
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz   8GB
#
#                 Memory                           Gpu  OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS  1.37kg
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS  1.34kg
# 2            256GB SSD         Intel HD Graphics 620  No OS  1.86kg
# 3            512GB SSD            AMD Radeon Pro 455  macOS  1.83kg
# 4            256GB SSD  Intel Iris Plus Graphics 650  macOS  1.37kg
#
#    Price_euros
# 0      1339.69
# 1       898.94
# 2       575.00
# 3      2537.45
# 4      1803.60

# %%
analyzer = DataAnalyzer(dataframe=df,llm=llama3b)
visualizer = Visualizer(dataframe=df)

# %%
analysis = analyzer.analysis_data()
analysis
# Out:
# "Based on the provided dataset, I'll analyze the data and provide insights:\n\n**Key Trends and Patterns:**\n\n1. **Price variability:** The Price_euros column shows a wide range of values (from €174 to €6099), indicating that prices vary significantly among laptops. This suggests that there might be opportunities for differentiation or bundling based on price tiers.\n2. **Screen Resolution:** The ScreenResolution column has a relatively consistent distribution, with most laptops featuring Full HD (1920x1080) or Retina Display (2560x1600) screens. This indicates that manufacturers focus on delivering high-quality visuals.\n3. **CPU and RAM combinations:** The Intel Core i5 processor is the most common CPU among these laptops, followed by i7 processors. RAM ranges from 8GB to 16GB, suggesting a mix of budget-friendly and high-end configurations.\n4. **Inches distribution:** Laptop screen sizes range from 10 inches to 18 inches, with an average size around 15 inches.\n\n**Recommendations or Actionable Insights:**\n\n1. **Target higher price tiers:** Given the significant drop-off in prices at the €1000-€1500 mark, it might be beneficial to focus on higher-end laptops (€2000+), where margins can be more substantial.\n2. **Screen resolution and display quality:** With the prevalence of Full HD and Retina Display screens, manufacturers could consider investing in advanced display technologies or partnering with suppliers to improve screen quality and user experience.\n3. **CPU and RAM optimization:** Optimizing CPU-RAM combinations could lead to improved performance, battery life, and overall user satisfaction. Manufacturers might want to explore more efficient processor architectures, RAM speeds, or caching techniques.\n4. **Battery life and power efficiency:** Although not directly related to the provided data, considering battery life and power efficiency would be crucial for laptops, as users increasingly expect devices that can last longer on a single charge.\n5. **Product differentiation:** To stand out in a crowded market, manufacturers could differentiate their products through innovative features (e.g., touchscreen capabilities, advanced cooling systems), improved designs, or unique software experiences.\n\n**Actionable Recommendations:**\n\nBased on these insights, here are some actionable recommendations:\n\n1. Conduct customer surveys to better understand user preferences and pain points related to laptops.\n2. Gather market research data to identify gaps in the current laptop offerings and opportunities for differentiation.\n3. Develop targeted marketing campaigns highlighting specific product features or price tiers that resonate with your target audience.\n4. Collaborate with suppliers to explore advanced display technologies, efficient processor architectures, or power management techniques.\n5. Consider introducing new product lines or editions to cater to different user segments (e.g., budget-friendly, gaming-focused, business-oriented).\n\nBy addressing these trends and patterns, manufacturers can create more competitive products that meet the evolving needs of users in this fast-paced technology landscape."

# %%
print(analyzer.memory[1])
# Out:
# content="Based on the provided dataset, here are my analysis, key trends, patterns, and recommendations:\n\n**Key Trends and Patterns:**\n\n1. **Price Variation:** The average price of laptops is around €1124 (€599 at 25th percentile to €1487 at 75th percentile). There's a significant variation in prices, with some laptops costing as low as €174 or as high as €6099.\n2. **Screen Resolution:** Most laptops have a screen resolution between 1440x900 and 2560x1600 (IPS Panel Retina Display), indicating a preference for good display quality.\n3. **Processor Performance:** Intel Core i5 processors are the most common, followed by AMD Radeon Pro graphics cards. This suggests that manufacturers prioritize performance over other aspects like battery life or portability.\n4. **Weight and Durability:** The majority of laptops weigh between 1 kg to 2 kg (1.34kg to 1.86kg), indicating a focus on balance between weight, durability, and usability.\n5. **Operating System:** macOS dominates the market, suggesting that Apple's ecosystem is a preferred choice for many customers.\n\n**Recommendations:**\n\n1. **Target Price Segment:** Manufacturers should consider targeting the €599-€977 price segment for laptops, as this range offers a balance between affordability and performance.\n2. **Display Quality:** Emphasize the importance of display quality (e.g., IPS Panel Retina Display) to cater to customers seeking good visual experience.\n3. **Processor Performance:** Consider offering a mix of Intel Core i5 and AMD Radeon Pro options to appeal to different customer segments, balancing performance with affordability.\n4. **Weight and Portability:** Design laptops that balance weight, durability, and portability to cater to various user preferences.\n5. **Expand Ecosystem Options:** Consider expanding the operating system options beyond macOS to include Windows or Chrome OS, which could attract a broader range of customers.\n\n**Actionable Insights:**\n\n1. **Product Line Refresh:** Review and refresh product lines to ensure that they align with current market trends and customer demands.\n2. **Competitor Analysis:** Conduct thorough competitor analysis to identify gaps in the market and opportunities for differentiation.\n3. **Marketing Strategy:** Develop a marketing strategy that targets the identified price segment, emphasizing display quality, processor performance, weight, and portability.\n4. **Product Development:** Prioritize product development based on customer preferences, focusing on laptops with IPS Panel Retina Display, Intel Core i5 processors, and balanced weights.\n5. **Customer Segmentation:** Identify specific customer segments (e.g., professionals, gamers) and tailor products to meet their unique needs.\n\nBy considering these trends, patterns, recommendations, actionable insights, and market conditions, manufacturers can develop targeted strategies to improve their laptop offerings and stay competitive in the market." additional_kwargs={} response_metadata={}

# %%
questions = analyzer.questions_gen(4)
# Out:
# 🔹 Raw LLM Output: "Here are four analysis questions about the dataset:\n\n1. What is the average price of laptops sold by each company?\n\nThis question can be answered by calculating the mean value of the 'Price_euros' column for each unique value in the 'Company' column.\n\n2. How does the weight of laptops change with their screen resolution?\n\nThis question can be answered by analyzing the relationship between the 'Weight' and 'ScreenResolution' columns. A scatterplot or regression analysis could be used to explore this relationship.\n\n3. What is the distribution of laptop types (TypeNames) and how do they relate to price and inches?\n\nThis question can be answered by exploring the distribution of unique values in the 'TypeName' column, as well as their relationships with other columns such as 'Price_euros' and 'Inches'. This could involve creating histograms, boxplots, or scatterplots to visualize these relationships.\n\n4. What is the average price-to-weight ratio for laptops from each company?\n\nThis question can be answered by calculating the mean value of the 'Price_euros' column divided by the 'Weight' column for each unique value in the 'Company' column. This ratio could provide insight into whether certain companies are selling higher-priced or lower-priced laptops compared to their competitors."
# 🟢 Extracted Questions List: ['What is the average price of laptops sold by each company?', 'How does the weight of laptops change with their screen resolution?', 'What is the distribution of laptop types (TypeNames) and how do they relate to price and inches?', 'What is the average price-to-weight ratio for laptops from each company?']

# %%
ques_list = ['What is the average price of laptops sold by each company?',
              'How does the weight of laptops change with their screen resolution?',
                'What is the distribution of laptop types (TypeNames) and how do they relate to price and inches?', 
                'What is the average price-to-weight ratio for laptops from each company?']

# %%
charts =[]
columns = []
for question in ques_list:
    charts.append(analyzer.select_chart_type(question))
    columns.append(analyzer.select_columns(question))

# %%
charts
# Out:
# ['Bar', 'XY', 'Pie', 'XY']

# %%
ques_list[0]
# Out:
# 'What is the average price of laptops and how does it compare to the median price?'

# %%
columns
# Out:
# [['Company', 'Price_euros'],
#  ['Weight', 'ScreenResolution'],
#  ['Price_euros'],
#  ['Price_euros', 'Weight']]

# %%
visualizer.set_style('DarkSolarizedStyle')

# %%
chart1 = visualizer.generate_visualization(
    question=ques_list[0],
    output_path="visualizationTest/v1.html",
    columns=columns[0],  # Optional override
    chart_type=charts[0],  # Optional override
    width=1200,
    height=800
)

# %%
chart1 = visualizer.generate_visualization(
    question=ques_list[1],
    output_path="visualizationTest/v2.html",
    columns=columns[1],  # Optional override
    chart_type='Scatter',  # Optional override
    width=1200,
    height=800
)

# %%
chart1 = visualizer.generate_visualization(
    question=ques_list[2],
    output_path="visualization/v3.html",
    columns=columns[2],  # Optional override
    chart_type=charts[2],  # Optional override
    width=1200,
    height=800
)

# %%
chart1 = visualizer.generate_visualization(
    question=ques_list[3],
    output_path="visualizationTest/v4.html",
    columns=columns[3],  # Optional override
    chart_type='Scatter',  # Optional override
    width=1200,
    height=800
)
