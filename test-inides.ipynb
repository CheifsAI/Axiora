# %%
from Models import llama3b 
from Main import summerizer 
from OprFuncs import csvpd

# %%
df = csvpd("Test_Datasets\supply_chain_data.csv")
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\s'
# <>:1: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\hasso\AppData\Local\Temp\ipykernel_24340\1270179709.py:1: SyntaxWarning: invalid escape sequence '\s'
#   df = csvpd("Test Datasets\supply_chain_data.csv")
# This appears to be a summary of the structure and content of a pandas DataFrame, which is a data structure in Python for data manipulation and analysis.
#
# Here's a breakdown of what each section means:
#
# 1. **RangeIndex**: This indicates that the DataFrame has an index ranging from 0 to 99, meaning it contains 100 entries.
#
# 2. **Data columns**: This lists the different columns in the DataFrame. There are 24 columns in total.
#
# 3. **Column information**:
#    - The first column ("Product type") is of type object and contains non-null values (i.e., no missing or null values).
# ...

# %%
from OprFuncs import data_infer

# %%
dinf = data_infer(df)

# %%
print(dinf)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 24 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Product type             100 non-null    object
#  1   SKU                      100 non-null    object
#  2   Price                    100 non-null    float64
#  3   Availability             100 non-null    int64
#  4   Number of products sold  100 non-null    int64
#  5   Revenue generated        100 non-null    float64
#  6   Customer demographics    100 non-null    object
#  7   Stock levels             100 non-null    int64
#  8   Supplier  Lead times     100 non-null    int64
#  9   Order quantities         100 non-null    int64
#  10  Shipping times           100 non-null    int64
#  11  Shipping carriers        100 non-null    object
#  12  Shipping costs           100 non-null    float64
#  13  Supplier name            100 non-null    object
# ...

# %%
ques = llama3b.invoke(f"create 4 anlysis questions about {dinf}")

# %%
print(ques)
# Out:
# Here are four analysis questions based on the provided DataFrame:
#
# 1. **What is the distribution of Product type and Customer demographics columns?**
#
# This question can be answered by looking at the `Non-Null Count` column for these two columns, which indicates that both columns have 100 entries with no missing values.
#
# 2. **Is there a correlation between Price and Revenue generated?**
#
# This question requires analyzing the data to see if there is any relationship between the price of products and the revenue generated from those sales.
#
# 3. **How does the availability of products affect the Number of products sold and Revenue generated?**
#
# This question can be answered by looking at the distribution of these two columns and seeing if there is any correlation between them, such as a positive relationship where higher availability leads to more sales and revenue.
#
# ...

# %%
viscode = llama3b.invoke(f"I already have a dataframe named 'df', Only create matplotlib code for each question in{ques} with the columns {dinf} in one python script")

# %%
print(viscode)
# Out:
# Below is a Python script that uses matplotlib to visualize the distribution of 'Product type' and 'Customer demographics' columns, plot a scatter plot to analyze the correlation between 'Price' and 'Revenue generated', plot another scatter plot to analyze the relationship between 'Availability' and both 'Number of products sold' and 'Revenue generated', and lastly plot histograms for 'Price', 'Revenue generated', 'Availability', 'Number of products sold'.
#
# ```python
# import matplotlib.pyplot as plt
# import pandas as pd
#
# # Assuming df is your DataFrame
#
# # Distribution of Product type and Customer demographics columns
# plt.figure(figsize=(10,5))
# plt.subplot(1, 2, 1)
# df['Product type'].value_counts().plot(kind='bar')
# plt.title('Distribution of Product Type')
#
# plt.subplot(1, 2, 2)
# df['Customer demographics'].value_counts().plot(kind='bar')
# plt.title('Distribution of Customer Demographics')
#
# # Correlation between Price and Revenue generated
# ...

# %%
from OprFuncs import extract_code 
visualcode = extract_code(viscode)

# %%
print(visualcode)
# Out:
# import matplotlib.pyplot as plt
# import pandas as pd
#
# # Assuming df is your DataFrame
#
# # Distribution of Product type and Customer demographics columns
# plt.figure(figsize=(10,5))
# plt.subplot(1, 2, 1)
# df['Product type'].value_counts().plot(kind='bar')
# plt.title('Distribution of Product Type')
#
# plt.subplot(1, 2, 2)
# df['Customer demographics'].value_counts().plot(kind='bar')
# plt.title('Distribution of Customer Demographics')
#
# # Correlation between Price and Revenue generated
# plt.figure(figsize=(8,6))
# plt.scatter(df['Price'], df['Revenue generated'])
# plt.title('Correlation between Price and Revenue Generated')
# plt.xlabel('Price')
# plt.ylabel('Revenue Generated')
#
# # Relationship between Availability and Number of products sold/Revenue generated
# plt.figure(figsize=(10,5))
#
# plt.subplot(1, 2, 1)
# plt.scatter(df['Availability'], df['Number of products sold'])
# plt.title('Relationship between Availability and Number of Products Sold')
# ...

# %%
exec(visualcode)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 exec(visualcode)
#
# File <string>:53
#
# File c:\Users\hasso\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\pyplot.py:1440, in subplot(*args, **kwargs)
#    1437 fig = gcf()
#    1439 # First, search for an existing subplot with a matching spec.
# -> 1440 key = SubplotSpec._from_subplot_args(fig, args)
#    1442 for ax in fig.axes:
#    1443     # If we found an Axes at the position, we can re-use it if the user passed no
#    1444     # kwargs or if the axes class and kwargs are identical.
#    1445     if (ax.get_subplotspec() == key
#    1446         and (kwargs == {}
#    1447              or (ax._projection_init
#    1448                  == fig._process_projection_requirements(**kwargs)))):
#
# ...

# %%
print(type(visualcode))  # Should print <class 'str'>
# Out:
# <class 'str'>

# %%
# Replace the specific line with a comment
visualcode = visualcode.replace("df = pd.read_csv('yourfile.csv')", "# df = pd.read_csv('yourfile.csv')")

# Print or verify the modified code
print(visualcode)
# Out:
# # Import necessary libraries
# import matplotlib.pyplot as plt
# from pandas import DataFrame
# import seaborn as sns
#
# # Create a sample dataframe (in real-world scenario, you would use your actual df)
# df = DataFrame({
# 'Product type': ['A', 'B', 'C'] * 100,
# 'Customer demographics': ['Demographics1', 'Demographics2', 'Demographics3'] * 100,
# 'Price': [10.0] * 100,
# 'Availability': [5, 10, 15] * 100,
# 'Number of products sold': [10, 20, 30] * 100,
# 'Revenue generated': [100.0] * 100
# })
#
# # Question 1: What is the distribution of Product type and Customer demographics columns?
# # We can use seaborn's countplot to visualize the distribution
# plt.figure(figsize=(10,6))
# sns.countplot(x='Product type', data=df)
# plt.title('Distribution of Product Type')
# plt.show()
#
# sns.countplot(x='Customer demographics', data=df)
# plt.title('Distribution of Customer Demographics')
# plt.show()
#
# # Question 2: Is there a correlation between Price and Revenue generated?
# ...
